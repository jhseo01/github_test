# %% [markdown]
# <a href="https://colab.research.google.com/github/jhseo01/github_test/blob/main/AutoEncoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 32)                25120
#
#  dense_1 (Dense)             (None, 784)               25872
#
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 32)                25120
#
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense_1 (Dense)             (None, 784)               25872
#
# =================================================================
# Total params: 25,872
# Trainable params: 25,872
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape, x_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
x_train[0].shape, x_test[0].shape
# Out:
# ((28, 28), (28, 28))

# %%
x_train[0].ndim
# Out:
# 2

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 2/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 3/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 4/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 5/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 6/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 7/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 8/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 9/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 10/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 11/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 14/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 16/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 17/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 21/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 22/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 23/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 24/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 25/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 26/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 27/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 28/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 29/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 32/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 33/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 34/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 35/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 36/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 38/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 39/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 40/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 41/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 42/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 43/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 45/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 46/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 47/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 48/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 49/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 50/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 51/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 52/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 53/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 54/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 55/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 56/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 57/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 58/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 59/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 60/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 61/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 62/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 63/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 64/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 65/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 66/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 67/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 68/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 69/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 70/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 71/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 72/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 73/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 74/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 76/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 77/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 78/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 79/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 80/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 81/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 82/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 83/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 84/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 85/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 86/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 87/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 88/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 89/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 91/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 92/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 93/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 94/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 95/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 98/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 100/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
encoded_imgs.shape, decoded_imgs.shape
# Out:
# ((10000, 32), (10000, 784))

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Adding a sparsity constraint on the encoded representations

# %%
from keras import regularizers

encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4065 - val_loss: 0.1020
# Epoch 2/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0460 - val_loss: 0.0211
# Epoch 3/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0151 - val_loss: 0.0111
# Epoch 4/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0094 - val_loss: 0.0082
# Epoch 5/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 6/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 7/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 8/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 9/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 10/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 11/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 14/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 16/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 17/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 21/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 23/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 24/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 25/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 26/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 27/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 28/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 29/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 32/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 33/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 34/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 35/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 36/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 38/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 39/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 40/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 41/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 42/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 43/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 45/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 46/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 47/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 48/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 49/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 50/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 51/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 52/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 53/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 54/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 55/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 56/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 57/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 58/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 59/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 60/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 61/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 62/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 63/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 64/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 65/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 66/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 67/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 68/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 69/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 70/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 71/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 72/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 73/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 74/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 76/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 77/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 78/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 79/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 80/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 81/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 82/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 83/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 84/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 85/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 86/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 87/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 88/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 89/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 91/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 92/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 93/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 94/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 95/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 98/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 100/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Deep autoencoder

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 2s 5ms/step - loss: 0.0893 - val_loss: 0.0041
# Epoch 2/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 3/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 5/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 6/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 7/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 8/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 9/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 10/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 11/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 14/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 16/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 17/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 21/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 22/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 23/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 24/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 25/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 26/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 27/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 28/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 29/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 32/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 33/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 34/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 35/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 38/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 39/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 40/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 41/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 42/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 43/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 45/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 46/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 47/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 48/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 49/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 50/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 51/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 52/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 53/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 54/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 55/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 56/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 57/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 58/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 59/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 60/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 61/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 62/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 63/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 64/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 65/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 66/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 67/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 68/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 69/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 70/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 71/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 72/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 73/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 74/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 76/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 77/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 78/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 79/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 80/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 81/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 82/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 83/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 84/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 85/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 86/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 87/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 88/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 89/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 91/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 93/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 94/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 95/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 98/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 100/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0036 - val_loss: 0.0037

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Convolutional autoencoder

# %%
import keras
from keras import layers

input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
from keras.callbacks import TensorBoard

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 469/469 [==============================] - 13s 6ms/step - loss: 0.2175 - val_loss: 0.1434
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1348 - val_loss: 0.1266
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1232 - val_loss: 0.1179
# Epoch 4/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1162 - val_loss: 0.1120
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1115 - val_loss: 0.1085
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1084 - val_loss: 0.1058
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1061 - val_loss: 0.1037
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1043 - val_loss: 0.1024
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1029 - val_loss: 0.1010
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1018 - val_loss: 0.1000
# Epoch 11/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1007 - val_loss: 0.0997
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0999 - val_loss: 0.0984
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0991 - val_loss: 0.0975
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0985 - val_loss: 0.0970
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0979 - val_loss: 0.0964
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0974 - val_loss: 0.0961
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0969 - val_loss: 0.0955
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0954
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0960 - val_loss: 0.0953
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0956 - val_loss: 0.0944
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0953 - val_loss: 0.0947
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0949 - val_loss: 0.0938
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0946 - val_loss: 0.0933
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0936
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0928
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0931
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0928
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0922
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0930 - val_loss: 0.0922
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0929 - val_loss: 0.0919
# Epoch 31/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0924 - val_loss: 0.0915
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0922 - val_loss: 0.0914
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0919 - val_loss: 0.0910
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0917 - val_loss: 0.0904
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0916 - val_loss: 0.0905
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0914 - val_loss: 0.0911
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0912 - val_loss: 0.0902
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0911 - val_loss: 0.0899
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0910 - val_loss: 0.0904
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0909 - val_loss: 0.0897
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0907 - val_loss: 0.0896
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0906 - val_loss: 0.0896
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0905 - val_loss: 0.0893
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0904 - val_loss: 0.0893
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0903 - val_loss: 0.0894
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0902 - val_loss: 0.0893
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0901 - val_loss: 0.0889
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0900 - val_loss: 0.0893

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# 128차원으로 인코딩된 표현도 살펴볼 수 있습니다. 이러한 표현은 8x4x4이므로 회색조 이미지로 표시할 수 있도록 4x32로 모양을 변경합니다.

# %%
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# 이미지 노이즈 제거에 적용

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/100
# 469/469 [==============================] - 5s 8ms/step - loss: 0.1577 - val_loss: 0.1147
# Epoch 2/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1121 - val_loss: 0.1074
# Epoch 3/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1071 - val_loss: 0.1041
# Epoch 4/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1043 - val_loss: 0.1020
# Epoch 5/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1025 - val_loss: 0.1010
# Epoch 6/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1013 - val_loss: 0.0998
# Epoch 7/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1004 - val_loss: 0.0993
# Epoch 8/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0995 - val_loss: 0.0987
# Epoch 9/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0989 - val_loss: 0.0977
# Epoch 10/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0983 - val_loss: 0.0973
# Epoch 11/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0978 - val_loss: 0.0967
# Epoch 12/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0974 - val_loss: 0.0964
# Epoch 13/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0970 - val_loss: 0.0960
# Epoch 14/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0966 - val_loss: 0.0958
# Epoch 15/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0964 - val_loss: 0.0956
# Epoch 16/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0961 - val_loss: 0.0953
# Epoch 17/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0959 - val_loss: 0.0951
# Epoch 18/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0957 - val_loss: 0.0949
# Epoch 19/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0956 - val_loss: 0.0949
# Epoch 20/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0954 - val_loss: 0.0950
# Epoch 21/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0953 - val_loss: 0.0945
# Epoch 22/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0951 - val_loss: 0.0944
# Epoch 23/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0951 - val_loss: 0.0945
# Epoch 24/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0949 - val_loss: 0.0942
# Epoch 25/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0948 - val_loss: 0.0941
# Epoch 26/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 27/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0941
# Epoch 28/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0946 - val_loss: 0.0941
# Epoch 29/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0945 - val_loss: 0.0939
# Epoch 30/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0945 - val_loss: 0.0941
# Epoch 31/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0944 - val_loss: 0.0945
# Epoch 32/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 33/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0943 - val_loss: 0.0945
# Epoch 34/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0942 - val_loss: 0.0942
# Epoch 35/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0942 - val_loss: 0.0938
# Epoch 36/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0942 - val_loss: 0.0936
# Epoch 37/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 38/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 39/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0941 - val_loss: 0.0935
# Epoch 40/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0940 - val_loss: 0.0937
# Epoch 41/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0940 - val_loss: 0.0936
# Epoch 42/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 43/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 44/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0935
# Epoch 45/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0935
# Epoch 46/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 47/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0938 - val_loss: 0.0935
# Epoch 48/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0938 - val_loss: 0.0935
# Epoch 49/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 50/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0938
# Epoch 51/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 52/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0941
# Epoch 53/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 54/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 55/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 56/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 57/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 58/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0937
# Epoch 59/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 60/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 61/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 62/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 63/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 64/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 65/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 66/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 67/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0936
# Epoch 68/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 69/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 70/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 71/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 72/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0931
# Epoch 73/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 74/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 75/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 76/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 77/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 78/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 79/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 80/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 81/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 82/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 83/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 84/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 85/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 86/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0930
# Epoch 87/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0930
# Epoch 88/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0934
# Epoch 89/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 90/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 91/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 92/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 93/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 94/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0932 - val_loss: 0.0930
# Epoch 95/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0932 - val_loss: 0.0935
# Epoch 96/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0931 - val_loss: 0.0930
# Epoch 97/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 98/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 99/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0931 - val_loss: 0.0931
# Epoch 100/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0931 - val_loss: 0.0931

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# 변형 자동 인코더(VAE)

# %%
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 186.5208 - val_loss: 168.5251
# Epoch 2/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 166.0858 - val_loss: 163.8862
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 162.8425 - val_loss: 161.9471
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 160.9634 - val_loss: 160.2191
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 159.0988 - val_loss: 158.3674
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 157.4507 - val_loss: 156.9643
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 156.2311 - val_loss: 155.8911
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 155.3531 - val_loss: 155.3573
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 154.6574 - val_loss: 154.5165
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 154.0822 - val_loss: 154.1995
# Epoch 11/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 153.5555 - val_loss: 153.6720
# Epoch 12/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 153.0953 - val_loss: 153.3009
# Epoch 13/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 152.6257 - val_loss: 152.9586
# Epoch 14/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 152.2261 - val_loss: 152.5890
# Epoch 15/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 151.8313 - val_loss: 152.1273
# Epoch 16/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 151.4658 - val_loss: 152.0989
# Epoch 17/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 151.1501 - val_loss: 151.8468
# Epoch 18/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.8481 - val_loss: 151.2487
# Epoch 19/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.5493 - val_loss: 151.2041
# Epoch 20/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.2460 - val_loss: 150.8484
# Epoch 21/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.0182 - val_loss: 150.8056
# Epoch 22/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.7741 - val_loss: 150.4802
# Epoch 23/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.5594 - val_loss: 150.1992
# Epoch 24/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 149.3377 - val_loss: 150.0998
# Epoch 25/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.1834 - val_loss: 150.0362
# Epoch 26/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.9857 - val_loss: 149.7071
# Epoch 27/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.8138 - val_loss: 149.5559
# Epoch 28/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.6451 - val_loss: 149.4644
# Epoch 29/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.4995 - val_loss: 149.5393
# Epoch 30/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.3447 - val_loss: 149.5133
# Epoch 31/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.2081 - val_loss: 149.2465
# Epoch 32/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.0353 - val_loss: 149.1920
# Epoch 33/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.9382 - val_loss: 149.0509
# Epoch 34/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.8157 - val_loss: 148.9464
# Epoch 35/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 147.7102 - val_loss: 148.8796
# Epoch 36/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.5650 - val_loss: 148.9884
# Epoch 37/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.4630 - val_loss: 148.7137
# Epoch 38/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.3483 - val_loss: 148.5566
# Epoch 39/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.2399 - val_loss: 148.9823
# Epoch 40/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.1664 - val_loss: 148.6814
# Epoch 41/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.0549 - val_loss: 148.2969
# Epoch 42/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.9668 - val_loss: 148.4083
# Epoch 43/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.8548 - val_loss: 148.7724
# Epoch 44/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.7974 - val_loss: 148.4637
# Epoch 45/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.7246 - val_loss: 148.2970
# Epoch 46/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.5870 - val_loss: 148.2638
# Epoch 47/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.5088 - val_loss: 148.0661
# Epoch 48/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 146.4517 - val_loss: 148.1694
# Epoch 49/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.3536 - val_loss: 147.8572
# Epoch 50/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.2924 - val_loss: 148.5493
# Epoch 51/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.2231 - val_loss: 148.0331
# Epoch 52/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 146.1690 - val_loss: 147.7964
# Epoch 53/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.0751 - val_loss: 148.1000
# Epoch 54/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.9807 - val_loss: 147.8911
# Epoch 55/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.9143 - val_loss: 147.8475
# Epoch 56/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.8755 - val_loss: 147.6963
# Epoch 57/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.8145 - val_loss: 147.4843
# Epoch 58/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.7545 - val_loss: 147.7294
# Epoch 59/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.6630 - val_loss: 147.6834
# Epoch 60/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.6159 - val_loss: 147.5608
# Epoch 61/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.5795 - val_loss: 147.6120
# Epoch 62/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.4909 - val_loss: 147.5477
# Epoch 63/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.4644 - val_loss: 147.6258
# Epoch 64/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.3952 - val_loss: 147.6434
# Epoch 65/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.3323 - val_loss: 147.4632
# Epoch 66/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.3134 - val_loss: 147.5508
# Epoch 67/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.2510 - val_loss: 147.3242
# Epoch 68/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.1749 - val_loss: 147.2464
# Epoch 69/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.1447 - val_loss: 147.3878
# Epoch 70/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.0869 - val_loss: 147.1143
# Epoch 71/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.0567 - val_loss: 147.2260
# Epoch 72/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.9814 - val_loss: 147.3117
# Epoch 73/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.9531 - val_loss: 147.0936
# Epoch 74/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.9095 - val_loss: 147.0849
# Epoch 75/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.8624 - val_loss: 147.0285
# Epoch 76/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 144.8177 - val_loss: 147.0172
# Epoch 77/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.7731 - val_loss: 147.0810
# Epoch 78/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.7672 - val_loss: 147.1118
# Epoch 79/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 144.7097 - val_loss: 147.1223
# Epoch 80/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.6707 - val_loss: 147.1143
# Epoch 81/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.6285 - val_loss: 146.8994
# Epoch 82/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 144.5855 - val_loss: 147.0748
# Epoch 83/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 144.5824 - val_loss: 146.9516
# Epoch 84/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.5094 - val_loss: 146.8774
# Epoch 85/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.5060 - val_loss: 146.9297
# Epoch 86/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.4669 - val_loss: 147.0153
# Epoch 87/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.4264 - val_loss: 147.0138
# Epoch 88/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.3695 - val_loss: 147.0517
# Epoch 89/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.3646 - val_loss: 146.7439
# Epoch 90/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.3244 - val_loss: 147.0441
# Epoch 91/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.3035 - val_loss: 147.3580
# Epoch 92/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.2732 - val_loss: 146.7886
# Epoch 93/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.2477 - val_loss: 146.9633
# Epoch 94/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.2021 - val_loss: 146.7503
# Epoch 95/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.1811 - val_loss: 146.6905
# Epoch 96/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.1521 - val_loss: 146.6805
# Epoch 97/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.1273 - val_loss: 146.9681
# Epoch 98/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.0638 - val_loss: 146.6007
# Epoch 99/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.0592 - val_loss: 146.7202
# Epoch 100/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.0169 - val_loss: 146.6185

# %%
x_test_encoded = encoder.predict(x_test, batch_size=32)
x_test_encoded = np.array(x_test_encoded)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1])
plt.colorbar()
plt.show()

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
